# %%
# Check GPU

import torch
print(torch.cuda.is_available())      # GPU?
print(torch.cuda.get_device_name(0))  # GPU name
# Out:
# True
# Quadro T2000 with Max-Q Design

# %%
# Check environment variables

import os
print("HF_HOME:", os.environ.get("HF_HOME"))
print("DIFFUSERS_CACHE:", os.environ.get("DIFFUSERS_CACHE"))
print("TORCH_HOME:", os.environ.get("TORCH_HOME"))
# Out:
# HF_HOME: D:\hf_cache
# DIFFUSERS_CACHE: D:\hf_cache\diffusers
# TORCH_HOME: D:\torch_cache

# %% [markdown]
# ## Using Model

# %%
import torch
from diffusers import StableDiffusionPipeline

# %%
pipe = StableDiffusionPipeline.from_pretrained(
    model_id,
    torch_dtype=torch.float32  # instead of float16
)
# Out:
# ...
# Loading weights:   1%|▏               | 4/396 [00:00<00:05, 69.95it/s, Materializing param=special_care_embeds_weights]
# Loading weights:   1%| | 5/396 [00:00<00:05, 73.36it/s, Materializing param=vision_model.vision_model.embeddings.class_
# Loading weights:   1%| | 5/396 [00:00<00:05, 69.80it/s, Materializing param=vision_model.vision_model.embeddings.class_
# Loading weights:   2%| | 6/396 [00:00<00:04, 83.76it/s, Materializing param=vision_model.vision_model.embeddings.patch_
# Loading weights:   2%| | 6/396 [00:00<00:04, 83.76it/s, Materializing param=vision_model.vision_model.embeddings.patch_
# Loading weights:   2%| | 7/396 [00:00<00:04, 86.92it/s, Materializing param=vision_model.vision_model.embeddings.positi
# Loading weights:   2%| | 7/396 [00:00<00:04, 85.86it/s, Materializing param=vision_model.vision_model.embeddings.positi
# Loading weights:   2%| | 8/396 [00:00<00:04, 95.78it/s, Materializing param=vision_model.vision_model.encoder.layers.0.
# ...

# %%
pipe = pipe.to("cuda")  
pipe.safety_checker = None
prompt = "A wide cinematic mountain landscape, sunrise, volumetric lighting, high detail, nature photography, 8k, ultra realistic"
image = pipe(prompt, num_inference_steps=25).images[0]
image.save("gpu_result_2.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [03:30<00:00,  8.41s/it]

# %%
pipe = pipe.to("cuda")  
pipe.safety_checker = None
prompt = "A man in red shirt, sunrise, sea"
image = pipe(prompt, num_inference_steps=25).images[0]
image.save("gpu_result_3.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [03:25<00:00,  8.23s/it]

# %%
pipe = pipe.to("cuda")  
pipe.safety_checker = None
prompt = "Robots trying to takeover the world"
image = pipe(prompt, num_inference_steps=25).images[0]
image.save("gpu_result_3.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [03:28<00:00,  8.35s/it]

# %%
pipe = pipe.to("cuda")  
pipe.safety_checker = None
prompt = "A cinematic scene of robots attempting to take over the world, city in chaos, flying drones, sparks and smoke, dramatic lighting, ultra-detailed, 8k, concept art, trending on ArtStation, highly realistic"
image = pipe(prompt, num_inference_steps=25).images[0]
image.save("gpu_result_4.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [03:27<00:00,  8.30s/it]

# %%
pipe = pipe.to("cuda")  
pipe.safety_checker = None
prompt = "A scene of robots attempting to take over the world, flying multiple drones, smoke, lighting, concept art, realistic"
image = pipe(prompt, num_inference_steps=25).images[0]
image.save("gpu_result_5.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [03:29<00:00,  8.37s/it]

# %%
pipe = pipe.to("cuda")  
pipe.safety_checker = None
prompt = "A scene of robots attempting to take over the world, flying multiple drones, robots with guns, smoke and fire, realistic"
image = pipe(prompt, num_inference_steps=25).images[0]
image.save("gpu_result_6.png")
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 25/25 [03:29<00:00,  8.38s/it]
